# %%
from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2022-01-01 09:47:42.291668
# date and time = 01/01/2022 09:47:42

# %%
from math import pi

r = float(input ("Enter radius of circle : "))

print ("Area of the circle is: " + str(pi * r**2))
# Out:
# Enter radius of circle : 7
# Area of the circle is: 153.93804002589985

# %%
first_name = input("Enter your First Name: ")
last_name = input("Enter your Last Name: ")
print(f"{first_name[::-1].strip()} {last_name[::-1].strip()}")
# Out:
# Enter your First Name: hasham
# Enter your Last Name: waheed
# mahsah deehaw

# %%
# Store input numbers
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')

# Add two numbers
sum = float(num1) + float(num2)

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number: 2
# Enter second number: 4
# The sum of 2 and 4 is 6.0

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
